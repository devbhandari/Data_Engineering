# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("LocalSpark") \
    .getOrCreate()

data = [("Dev", 100), ("Aryan", 200)]

df = spark.createDataFrame(data, ["name", "score"])

df.show()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/05/04 19:03:00 WARN Utils: Your hostname, Devs-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 192.168.0.101 instead (on interface en0)
# 26/05/04 19:03:00 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/04 19:03:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +-----+-----+
# | name|score|
# +-----+-----+
# |  Dev|  100|
# |Aryan|  200|
# +-----+-----+

# %%
pwd
# Out:
# '/Users/devbhandari/DevB/Learning/Study/spark-learning'

# %%
print('hello databricks')
# Out:
# hello databricks

# %% [markdown]
# #### Read CSV Using Spark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Lakehouse") \
    .getOrCreate()

df = spark.read.csv(
    "data/raw/orders.csv",
    header=True,
    inferSchema=True
)

df.show()
# Out:
# 26/05/04 19:19:26 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# +--------+--------+-------+------+
# |order_id|customer|country|amount|
# +--------+--------+-------+------+
# |       1|     Dev|  India|   100|
# |       2|   Aryan|    USA|   200|
# |       3|   Rahul|  India|   150|
# |       4|    John|     UK|   300|
# |       5|     Dev|  India|   120|
# +--------+--------+-------+------+

# %% [markdown]
# Bronze Layer

# %%
# Write Bronze
df.write.mode("overwrite").parquet("data/bronze/orders")

# %%
# Read Bronze:
bronze_df = spark.read.parquet("data/bronze/orders")

bronze_df.show()
# Out:
# +--------+--------+-------+------+
# |order_id|customer|country|amount|
# +--------+--------+-------+------+
# |       1|     Dev|  India|   100|
# |       2|   Aryan|    USA|   200|
# |       3|   Rahul|  India|   150|
# |       4|    John|     UK|   300|
# |       5|     Dev|  India|   120|
# +--------+--------+-------+------+

# %% [markdown]
# ### Silver Layer

# %%
from pyspark.sql.functions import col

silver_df = bronze_df.filter(
    col("amount") > 100
)

silver_df.show()
# Out:
# +--------+--------+-------+------+
# |order_id|customer|country|amount|
# +--------+--------+-------+------+
# |       2|   Aryan|    USA|   200|
# |       3|   Rahul|  India|   150|
# |       4|    John|     UK|   300|
# |       5|     Dev|  India|   120|
# +--------+--------+-------+------+

# %%
#write silver
silver_df.write.mode("overwrite").parquet("data/silver/orders")

# %%
#Read silver
silver_df = spark.read.parquet("data/silver/orders")

silver_df.show()
# Out:
# +--------+--------+-------+------+
# |order_id|customer|country|amount|
# +--------+--------+-------+------+
# |       2|   Aryan|    USA|   200|
# |       3|   Rahul|  India|   150|
# |       4|    John|     UK|   300|
# |       5|     Dev|  India|   120|
# +--------+--------+-------+------+

# %% [markdown]
# ### Gold Layer

# %%
gold_df = silver_df.groupBy("country").sum("amount")

gold_df.show()
# Out:
# +-------+-----------+
# |country|sum(amount)|
# +-------+-----------+
# |  India|        270|
# |    USA|        200|
# |     UK|        300|
# +-------+-----------+

# %% [markdown]
# ### Write Gold

# %%
gold_df.write.mode("overwrite").parquet("data/gold/orders")

# %%
##Read Gold
gold_df = spark.read.parquet("data/gold/orders")

gold_df.show()
# Out:
# +-------+-----------+
# |country|sum(amount)|
# +-------+-----------+
# |  India|        270|
# |    USA|        200|
# |     UK|        300|
# +-------+-----------+

# %%
import sys
print(sys.executable)
# Out:
# /Users/devbhandari/DevB/Learning/Study/spark-learning/venv/bin/python

# %%
# Test from vs code
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("VSCodeSpark") \
    .getOrCreate()

data = [("Dev", 100), ("Aryan", 200)]

df = spark.createDataFrame(data, ["name", "score"])

df.show()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/05/04 19:42:44 WARN Utils: Your hostname, Devs-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 192.168.0.101 instead (on interface en0)
# 26/05/04 19:42:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/04 19:42:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/05/04 19:42:45 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# +-----+-----+
# | name|score|
# +-----+-----+
# |  Dev|  100|
# |Aryan|  200|
# +-----+-----+
